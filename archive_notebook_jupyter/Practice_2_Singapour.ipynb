# %% [markdown]
# # Practice 2 Singapour

# %% [markdown]
# ## Import

# %%
import pandas as pd
import seaborn as sns
import datetime as dt


p2 = pd.read_csv('14_Singapore_data/p2.csv',sep=';')

# %%
p2.head()
# Out:
#        Name  DriverNum  Lap     Time  Elapsed  Stint Fuel Corrected Laptime  \
# 0  T. GLOCK         24    1  116,835  176,835      1                116,445
# 1  T. GLOCK         24    2  126,169  303,004      1                125,857
# 2  T. GLOCK         24    3  116,702  419,706      1                116,468
# 3  T. GLOCK         24    4  126,119  545,825      1                125,963
# 4  T. GLOCK         24    5  115,931  661,756      1                115,853
#
#    Stint Length  Lap in stint
# 0             6             1
# 1             6             2
# 2             6             3
# 3             6             4
# 4             6             5

# %%
p2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    487 non-null    object
#  1   DriverNum               487 non-null    int64
#  2   Lap                     487 non-null    int64
#  3   Time                    487 non-null    object
#  4   Elapsed                 487 non-null    object
#  5   Stint                   487 non-null    int64
#  6   Fuel Corrected Laptime  487 non-null    object
#  7   Stint Length            487 non-null    int64
#  8   Lap in stint            487 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 34.4+ KB

# %%
p2["Time_num"] =  p2["Time"].str.replace(',','.').astype(float)

# %%
rax = sns.swarmplot(data=p2,x="Time_num",y="Name")

# %%
sns.lineplot(x = 'Lap', y = 'Time_num',data=p2.query('Name == "V. PETROV"'))
# Out:
# <AxesSubplot:xlabel='Lap', ylabel='Time_num'>

# %%
p2.query('Name == "V. PETROV"')
# Out:
#           Name  DriverNum  Lap     Time   Elapsed  Stint  \
# 337  V. PETROV         10    1  112,779   147,779      1
# 338  V. PETROV         10    2  119,077   266,856      1
# 339  V. PETROV         10    3  112,036   378,892      1
# 340  V. PETROV         10    4  125,425   504,317      1
# 341  V. PETROV         10    6  111,963   1457,26      2
# 342  V. PETROV         10    7  117,252  1574,512      2
# 343  V. PETROV         10    8  112,982  1687,494      2
# 344  V. PETROV         10    9  123,645  1811,139      2
# 345  V. PETROV         10   11  110,399  2744,361      3
# 346  V. PETROV         10   12  117,836  2862,197      3
# 347  V. PETROV         10   13  120,577  2982,774      3
# 348  V. PETROV         10   15  117,477  3796,085      4
# 349  V. PETROV         10   16  119,215    3915,3      4
# 350  V. PETROV         10   17  118,296  4033,596      4
# 351  V. PETROV         10   18  118,505  4152,101      4
# ...
