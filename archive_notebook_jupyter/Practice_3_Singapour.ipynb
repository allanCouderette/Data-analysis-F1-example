# %% [markdown]
# # Practice 3 Singapour

# %% [markdown]
# ## Import

# %%
import pandas as pd
import seaborn as sns
import datetime as dt


p3 = pd.read_csv('14_Singapore_data/p3.csv',sep=';')

# %%
p3.head()
# Out:
#        Name  DriverNum  Lap     Time   Elapsed  Stint Fuel Corrected Laptime  \
# 0  T. GLOCK         24    2  117,277   781,905      1                117,121
# 1  T. GLOCK         24    3  116,201   898,106      1                116,123
# 2  T. GLOCK         24    4  135,203  1033,309      1                135,203
# 3  T. GLOCK         24    6  115,853    1685,5      2                115,697
# 4  T. GLOCK         24    7  115,624  1801,124      2                115,546
#
#    Stint Length  Lap in stint
# 0             3             1
# 1             3             2
# 2             3             3
# 3             3             1
# 4             3             2

# %%
p3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    293 non-null    object
#  1   DriverNum               293 non-null    int64
#  2   Lap                     293 non-null    int64
#  3   Time                    293 non-null    object
#  4   Elapsed                 293 non-null    object
#  5   Stint                   293 non-null    int64
#  6   Fuel Corrected Laptime  293 non-null    object
#  7   Stint Length            293 non-null    int64
#  8   Lap in stint            293 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 20.7+ KB

# %%
p3["Time_num"] =  p3["Time"].str.replace(',','.').astype(float)

# %%
rax = sns.swarmplot(data=p3,x="Time_num",y="Name")

# %%
sns.lineplot(x = 'Lap', y = 'Time_num',data=p3.query('Name == "V. PETROV"'))
# Out:
# <AxesSubplot:xlabel='Lap', ylabel='Time_num'>

# %%
p3.query('Name == "V. PETROV"')
# Out:
#           Name  DriverNum  Lap     Time   Elapsed  Stint  \
# 125  V. PETROV         10    2  119,106   828,674      1
# 126  V. PETROV         10    3  116,693   945,367      1
# 127  V. PETROV         10    4  115,802  1061,169      1
# 128  V. PETROV         10    5  114,736  1175,905      1
# 129  V. PETROV         10    6  114,866  1290,771      1
# 130  V. PETROV         10    7  141,685  1432,456      1
#
#     Fuel Corrected Laptime  Stint Length  Lap in stint  Time_num
# 125                118,716             6             1   119.106
# 126                116,381             6             2   116.693
# 127                115,568             6             3   115.802
# 128                 114,58             6             4   114.736
# 129                114,788             6             5   114.866
# 130                141,685             6             6   141.685
